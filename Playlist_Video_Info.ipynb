# %% [markdown]
# <a href="https://colab.research.google.com/github/the-y9/Playlist-Video-Info/blob/main/Playlist_Video_Info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
subject = "Managerial Economics"
playlist_url = r"https://youtube.com/playlist?list=PLZ2ps__7DhBaUpIodIKDFj_5JznWTxp1E&feature=shared"

# %%
# !pip show pytubefix || pip install pytubefix
# Out:
# WARNING: Package(s) not found: pytubefix
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 2.1 MB/s eta 0:00:00
# ...

# %%
from tqdm import tqdm

# %%
from pytubefix import Playlist

def get_playlist_videos_info(playlist_url):
    video_info_list = []  # Renamed list for clarity
    e=0
    try:
        # Create a Playlist object
        playlist = Playlist(playlist_url)
        i=1
        # Fetch the title and duration of each video
        for video in tqdm(playlist.videos):
            try:
                title = video.title
                duration = (video.length // 60)+(video.length%60*0.01)  # Convert seconds to minutes
                # print(f"Title: {title}, Duration: {duration} minutes")
                video_info_list.append((i,title, duration))

            except Exception as video_error:
                # print(f"An error occurred while processing video: {video_error}")
                video_info_list.append((i,'error', 'na'))
                e+=1
                if e/len(video_info_list) > 0.5:
                  break
            finally:
              i+=1

    except Exception as e:
        print(f"An error occurred: {e}")

    return video_info_list

video_info_list = get_playlist_videos_info(playlist_url)
print(f"Total Videos: {len(video_info_list)}")
video_info_list[:10]
# Out:
# 100%|██████████| 54/54 [00:03<00:00, 14.49it/s]
# Total Videos: 54
# [(1, 'Introduction', 33.24),
#  (2, 'Economic Models', 19.41),
#  (3, 'Problem Solving and Decision Making: Buyers Perspective', 43.32),
#  (4, 'Problem Solving and Decision Making:  Sellers Perspective', 38.07),
#  (5, 'Costs: Opportunity Cost and Sunk Cost', 36.32),
#  (6, 'Costs: Fixed Cost and Variable Cost', 19.13),
#  (7, 'Firm: A Simplified View', 41.53),
#  (8, 'Legal Organization of Firms', 19.14),
#  (9, 'Marginal Analysis Through Examples - Part 1', 21.02),
#  (10, 'Marginal Analysis Through Examples - Part 2', 7.11)]

# %%
# # .txt file
# with open(subject+'_Lec_Info.txt', 'w') as file:
#     for v in tqdm(video_info_list):
#         s = f"{v[0]}: {v[1]}: {v[2]} minutes."
#         file.write(s + '\n')
# Out:
# 100%|██████████| 54/54 [00:00<00:00, 94647.90it/s]

# %%
# .csv file
with open(subject+'_Lec_Info.csv', 'w') as file:
    file.write("Index, Title, Duration" + '\n')
    for v in tqdm(video_info_list):
        v = [str(i).replace(',', '') for i in v]
        s = f"{v[0]}, {v[1]}, {v[2]}"
        file.write(s + '\n')
# Out:
# 100%|██████████| 54/54 [00:00<00:00, 147168.56it/s]

# %%
import pandas as pd
st = subject+'_Lec_Info.csv'
df = pd.read_csv(st)
df
# Out:
#     Index                                              Title   Duration
# 0       1                                       Introduction      33.24
# 1       2                                    Economic Models      19.41
# 2       3   Problem Solving and Decision Making: Buyers P...      43.32
# 3       4   Problem Solving and Decision Making:  Sellers...      38.07
# 4       5              Costs: Opportunity Cost and Sunk Cost      36.32
# 5       6                Costs: Fixed Cost and Variable Cost      19.13
# 6       7                            Firm: A Simplified View      41.53
# 7       8                        Legal Organization of Firms      19.14
# 8       9        Marginal Analysis Through Examples - Part 1      21.02
# 9      10        Marginal Analysis Through Examples - Part 2       7.11
# 10     11            Marginal Rate of Technical Substitution      34.59
# 11     12                                Cost Minimization 1      24.27
# ...
